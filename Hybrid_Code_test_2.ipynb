# %% [markdown]
# ## This code is to combine results from various outputs for PGE Data using Year 1 (test data) and Year 2 (test data) to train and Year 3 to predicit

# %%
# Commonly used python functions and display settings
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.2f}'.format

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %%
# Key imports for this code (various ML and Stat Models)
from xgboost import XGBRegressor
from xgboost import XGBClassifier
from sklearn.linear_model import LinearRegression

# %%
import constants
import helper_methods

# %% [markdown]
# ## Train Individual Models and Generate Excel for Predictions

# %%
generate_individual_predictions = False

# %%
if generate_individual_predictions:
    # %run PK_MODEL.py
    # %run NG_MODEL.py
    # %run NU_MODEL.py
    # %run BY_MODEL.py

# %%
if generate_individual_predictions:
    # %run SA_MODEL.py

# %% [markdown]
# ## Get data and analyze

# %%
# fetch data from the excel file


sa_train_data = pd.read_excel(constants.SA_TEST_1)
sa_test_data = pd.read_excel(constants.SA_TEST_2)
sa = constants.SA_COL

by_train_data = pd.read_excel(constants.BY_TEST_1)
by_test_data = pd.read_excel(constants.BY_TEST_2)
by = constants.BY_COL


nu_train_data = pd.read_excel(constants.NU_TEST_1)
nu_test_data = pd.read_excel(constants.NU_TEST_2)
nu = constants.NU_COL


pk_train_data = pd.read_excel(constants.PK_TEST_1)
pk_test_data = pd.read_excel(constants.PK_TEST_2)
pk = constants.PK_COL


ng_train_data = pd.read_excel(constants.NG_TEST_1)
ng_test_data = pd.read_excel(constants.NG_TEST_2)
ng = constants.NG_COL

methods = [pk, sa, nu, by, ng]

allcols = ['Year', 'Month', 'Day', 'Hour', 'Load', 'Site-1 Temp', 'Site-2 Temp',
       'Site-3 Temp', 'Site-4 Temp', 'Site-5 Temp', 'Site-1 GHI', 'Site-2 GHI',
       'Site-3 GHI', 'Site-4 GHI', 'Site-5 GHI']

cols = ['Year', 'Month', 'Day', 'Hour']

train_data = ng_train_data[allcols + [ng]]
train_data = train_data.merge(pk_train_data[cols+[pk]], on = cols, how = 'left')
train_data = train_data.merge(by_train_data[cols+[by]], on = cols, how = 'left')
train_data = train_data.merge(nu_train_data[cols+[nu]], on = cols, how = 'left')
train_data = train_data.merge(sa_train_data[cols+[sa]], on = cols, how = 'left')

test_data = ng_test_data[allcols + [ng]]
test_data = test_data.merge(pk_test_data[cols+[pk]], on = cols, how = 'left')
test_data = test_data.merge(by_test_data[cols+[by]], on = cols, how = 'left')
test_data = test_data.merge(nu_test_data[cols+[nu]], on = cols, how = 'left')
test_data = test_data.merge(sa_test_data[cols+[sa]], on = cols, how = 'left')

train_data.head()
train_data.tail()

test_data.head()
test_data.tail()

# Finding how many rows of data we have and if there are any NaN values
len(train_data)
len(test_data)
train_data.isna().sum()
test_data.isna().sum()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     1      1    1     1  1997         8.00         8.20         5.30
# 1     1      1    1     2  1921         8.30         8.60         5.20
# 2     1      1    1     3  1861         8.10         8.80         5.10
# 3     1      1    1     4  1833         7.60         8.10         4.30
# 4     1      1    1     5  1847         7.30         7.50         4.00
#
#    Site-4 Temp  Site-5 Temp  Site-1 GHI  Site-2 GHI  Site-3 GHI  Site-4 GHI  \
# 0         9.40         8.10           0           0           0           0
# 1         8.60         7.10           0           0           0           0
# 2         8.70         6.20           0           0           0           0
# 3         8.50         6.00           0           0           0           0
# 4         8.60         6.90           0           0           0           0
#
#    Site-5 GHI  Model NG  Model PK  Model BY  Model NU  Model SA
# 0           0  1,935.31       NaN  1,931.47  1,905.52       NaN
# 1           0  1,860.35       NaN  1,852.36  2,100.16       NaN
# 2           0  1,829.12       NaN  1,814.53  2,077.88       NaN
# 3           0  1,817.96       NaN  1,815.76  2,062.45       NaN
# 4           0  1,905.81       NaN  1,882.84  2,007.13       NaN
#       Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 8779     1     12   31    20  2548        10.70        12.30        10.40
# 8780     1     12   31    21  2446         9.70        11.70         8.40
# 8781     1     12   31    22  2350         9.20        10.20         6.10
# 8782     1     12   31    23  2227         8.40         9.50         4.20
# 8783     1     12   31    24  2125         7.50         8.10         3.70
#
#       Site-4 Temp  Site-5 Temp  Site-1 GHI  Site-2 GHI  Site-3 GHI  \
# 8779        11.60        10.60           0           0           0
# 8780        11.00        12.30           0           0           0
# 8781        11.30        11.60           0           0           0
# 8782        10.50         8.50           0           0           0
# 8783         8.70         6.80           0           0           0
#
#       Site-4 GHI  Site-5 GHI  Model NG  Model PK  Model BY  Model NU  Model SA
# 8779           0           0  2,669.70  2,744.88  2,620.39  2,722.87  2,667.68
# 8780           0           0  2,590.76  2,647.25  2,559.21  2,608.06  2,592.53
# 8781           0           0  2,438.13  2,473.65  2,412.72  2,504.86  2,474.73
# 8782           0           0  2,377.31  2,360.37  2,299.92  2,388.27  2,266.51
# 8783           0           0  2,212.78  2,177.14  2,195.27  2,271.81  2,177.12
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     2      1    1     1  2021         6.70         7.40         2.90
# 1     2      1    1     2  1923         6.20         7.10         2.50
# 2     2      1    1     3  1855         6.00         7.10         2.40
# 3     2      1    1     4  1830         5.70         7.20         2.00
# 4     2      1    1     5  1844         7.40         8.30         4.20
#
#    Site-4 Temp  Site-5 Temp  Site-1 GHI  Site-2 GHI  Site-3 GHI  Site-4 GHI  \
# 0         7.10         5.90           0           0           0           0
# 1         6.70         6.00           0           0           0           0
# 2         7.20         6.30           0           0           0           0
# 3         7.90         8.60           0           0           0           0
# 4        11.40        12.40           0           0           0           0
#
#    Site-5 GHI  Model NG  Model PK  Model BY  Model NU  Model SA
# 0           0  1,991.57  1,976.26  1,989.82  1,992.32  1,972.31
# 1           0  1,905.37  1,933.52  1,900.49  1,950.43  1,897.57
# 2           0  1,812.80  1,867.68  1,833.55  1,866.50  1,886.81
# 3           0  1,749.44  1,894.85  1,781.64  1,809.24  1,894.87
# 4           0  1,862.80  1,944.38  1,811.23  1,835.14  1,905.08
#       Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 8755     2     12   31    20  2545        12.50        11.90        10.30
# 8756     2     12   31    21  2449        12.50        11.90         9.70
# 8757     2     12   31    22  2348        12.50        12.00         9.70
# 8758     2     12   31    23  2229        12.60        12.40         9.50
# 8759     2     12   31    24  2118        12.40        12.10         9.70
#
#       Site-4 Temp  Site-5 Temp  Site-1 GHI  Site-2 GHI  Site-3 GHI  \
# 8755        12.60        11.30           0           0           0
# 8756        12.60        11.20           0           0           0
# 8757        12.70        11.10           0           0           0
# 8758        12.70        11.00           0           0           0
# 8759        12.50        10.60           0           0           0
#
#       Site-4 GHI  Site-5 GHI  Model NG  Model PK  Model BY  Model NU  Model SA
# 8755           0           0  2,609.52  2,556.20  2,608.76  2,584.44  2,706.96
# 8756           0           0  2,509.41  2,444.91  2,529.14  2,489.97  2,529.90
# 8757           0           0  2,372.92  2,294.96  2,391.28  2,334.18  2,427.21
# 8758           0           0  2,195.36  2,208.06  2,227.20  2,167.55  2,206.03
# 8759           0           0  2,072.39  2,008.86  2,063.95  2,058.77  2,036.59
# 8784
# 8760
# Year            0
# Month           0
# Day             0
# Hour            0
# Load            0
# Site-1 Temp     0
# Site-2 Temp     0
# Site-3 Temp     0
# Site-4 Temp     0
# Site-5 Temp     0
# Site-1 GHI      0
# Site-2 GHI      0
# Site-3 GHI      0
# Site-4 GHI      0
# Site-5 GHI      0
# Model NG        0
# Model PK       48
# Model BY        0
# Model NU        0
# Model SA       24
# dtype: int64
# Year           0
# Month          0
# Day            0
# Hour           0
# Load           0
# Site-1 Temp    0
# Site-2 Temp    0
# Site-3 Temp    0
# Site-4 Temp    0
# Site-5 Temp    0
# Site-1 GHI     0
# Site-2 GHI     0
# Site-3 GHI     0
# Site-4 GHI     0
# Site-5 GHI     0
# Model NG       0
# Model PK       0
# Model BY       0
# Model NU       0
# Model SA       0
# dtype: int64

# %%
train_data['avg_to_impute'] =  (train_data[ng] + train_data[nu] )/ 2
train_data[pk].fillna(train_data['avg_to_impute'], inplace = True)
train_data[sa].fillna(train_data['avg_to_impute'], inplace = True)
train_data.drop(columns = ['avg_to_impute'], inplace = True)
train_data.head()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     1      1    1     1  1997         8.00         8.20         5.30
# 1     1      1    1     2  1921         8.30         8.60         5.20
# 2     1      1    1     3  1861         8.10         8.80         5.10
# 3     1      1    1     4  1833         7.60         8.10         4.30
# 4     1      1    1     5  1847         7.30         7.50         4.00
#
#    Site-4 Temp  Site-5 Temp  Site-1 GHI  Site-2 GHI  Site-3 GHI  Site-4 GHI  \
# 0         9.40         8.10           0           0           0           0
# 1         8.60         7.10           0           0           0           0
# 2         8.70         6.20           0           0           0           0
# 3         8.50         6.00           0           0           0           0
# 4         8.60         6.90           0           0           0           0
#
#    Site-5 GHI  Model NG  Model PK  Model BY  Model NU  Model SA
# 0           0  1,935.31  1,920.41  1,931.47  1,905.52  1,920.41
# 1           0  1,860.35  1,980.25  1,852.36  2,100.16  1,980.25
# 2           0  1,829.12  1,953.50  1,814.53  2,077.88  1,953.50
# 3           0  1,817.96  1,940.21  1,815.76  2,062.45  1,940.21
# 4           0  1,905.81  1,956.47  1,882.84  2,007.13  1,956.47

# %%
test_data['avg_to_impute'] =  (test_data[ng] + test_data[nu] ) / 2
test_data[pk].fillna(test_data['avg_to_impute'], inplace = True)
test_data[sa].fillna(test_data['avg_to_impute'], inplace = True)
test_data.drop(columns = ['avg_to_impute'], inplace = True)
test_data.head()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     2      1    1     1  2021         6.70         7.40         2.90
# 1     2      1    1     2  1923         6.20         7.10         2.50
# 2     2      1    1     3  1855         6.00         7.10         2.40
# 3     2      1    1     4  1830         5.70         7.20         2.00
# 4     2      1    1     5  1844         7.40         8.30         4.20
#
#    Site-4 Temp  Site-5 Temp  Site-1 GHI  Site-2 GHI  Site-3 GHI  Site-4 GHI  \
# 0         7.10         5.90           0           0           0           0
# 1         6.70         6.00           0           0           0           0
# 2         7.20         6.30           0           0           0           0
# 3         7.90         8.60           0           0           0           0
# 4        11.40        12.40           0           0           0           0
#
#    Site-5 GHI  Model NG  Model PK  Model BY  Model NU  Model SA
# 0           0  1,991.57  1,976.26  1,989.82  1,992.32  1,972.31
# 1           0  1,905.37  1,933.52  1,900.49  1,950.43  1,897.57
# 2           0  1,812.80  1,867.68  1,833.55  1,866.50  1,886.81
# 3           0  1,749.44  1,894.85  1,781.64  1,809.24  1,894.87
# 4           0  1,862.80  1,944.38  1,811.23  1,835.14  1,905.08

# %% [markdown]
# ## Classify to get best among the 7 methods

# %%
# Function to find the best method and its corresponding prediction
def find_best_method(row):
    errors = {method: abs(row[method] - row['Load']) for method in methods}
    best_method = max(errors, key=lambda k: (-errors[k], k))  # Prioritizing later columns in case of ties
    return best_method, row[best_method]

# Apply function to get best method and best prediction
train_data[['best', 'best_pred']] = train_data.apply(lambda row: pd.Series(find_best_method(row)), axis=1)

train_data.head()
train_data.tail()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     1      1    1     1  1997         8.00         8.20         5.30
# 1     1      1    1     2  1921         8.30         8.60         5.20
# 2     1      1    1     3  1861         8.10         8.80         5.10
# 3     1      1    1     4  1833         7.60         8.10         4.30
# 4     1      1    1     5  1847         7.30         7.50         4.00
#
#    Site-4 Temp  Site-5 Temp  ...  Site-3 GHI  Site-4 GHI  Site-5 GHI  \
# 0         9.40         8.10  ...           0           0           0
# 1         8.60         7.10  ...           0           0           0
# 2         8.70         6.20  ...           0           0           0
# 3         8.50         6.00  ...           0           0           0
# 4         8.60         6.90  ...           0           0           0
#
#    Model NG  Model PK  Model BY  Model NU  Model SA      best  best_pred
# 0  1,935.31  1,920.41  1,931.47  1,905.52  1,920.41  Model NG   1,935.31
# 1  1,860.35  1,980.25  1,852.36  2,100.16  1,980.25  Model SA   1,980.25
# 2  1,829.12  1,953.50  1,814.53  2,077.88  1,953.50  Model NG   1,829.12
# 3  1,817.96  1,940.21  1,815.76  2,062.45  1,940.21  Model NG   1,817.96
# 4  1,905.81  1,956.47  1,882.84  2,007.13  1,956.47  Model BY   1,882.84
#
# [5 rows x 22 columns]
#       Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 8779     1     12   31    20  2548        10.70        12.30        10.40
# 8780     1     12   31    21  2446         9.70        11.70         8.40
# 8781     1     12   31    22  2350         9.20        10.20         6.10
# 8782     1     12   31    23  2227         8.40         9.50         4.20
# 8783     1     12   31    24  2125         7.50         8.10         3.70
#
#       Site-4 Temp  Site-5 Temp  ...  Site-3 GHI  Site-4 GHI  Site-5 GHI  \
# 8779        11.60        10.60  ...           0           0           0
# 8780        11.00        12.30  ...           0           0           0
# 8781        11.30        11.60  ...           0           0           0
# 8782        10.50         8.50  ...           0           0           0
# 8783         8.70         6.80  ...           0           0           0
#
#       Model NG  Model PK  Model BY  Model NU  Model SA      best  best_pred
# 8779  2,669.70  2,744.88  2,620.39  2,722.87  2,667.68  Model BY   2,620.39
# 8780  2,590.76  2,647.25  2,559.21  2,608.06  2,592.53  Model BY   2,559.21
# 8781  2,438.13  2,473.65  2,412.72  2,504.86  2,474.73  Model BY   2,412.72
# 8782  2,377.31  2,360.37  2,299.92  2,388.27  2,266.51  Model SA   2,266.51
# 8783  2,212.78  2,177.14  2,195.27  2,271.81  2,177.12  Model SA   2,177.12
#
# [5 rows x 22 columns]

# %%
# Define mapping
class_mapping = {methods[i]: i for i in range(len(methods))}

# Apply mapping to 'best' column in df_train
train_data['best_encoded'] = train_data['best'].map(class_mapping)

# %%
# Creating training data dropping columns not needed and also ground truth
X_train = train_data.drop(columns = ['Year', 'Day', 'Load', 'best_pred', 'best', 'best_encoded'] + methods)
y_train = train_data['best_encoded']
X_test = test_data.drop(columns = ['Year', 'Day', 'Load'] + methods)

# %%
# Define the XGBoost regressor with specific hyperparameters
model = XGBClassifier(
        n_estimators=400,
        max_depth=5,
        learning_rate=0.05,
        subsample=1.0,
        colsample_bytree=0.6,
        objective='reg:squarederror',
        random_state=42
    )

# Train the model
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# Make predictions
# y_preds = gb.predict(X_test)
y_preds = model.predict(X_test)
y_preds
# Out:
# array([2, 4, 3, ..., 3, 0, 0])

# %%
test_data['best_encoded'] = y_preds
train_data['best_encoded_fcst'] = model.predict(X_train)
test_data.head()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     2      1    1     1  2021         6.70         7.40         2.90
# 1     2      1    1     2  1923         6.20         7.10         2.50
# 2     2      1    1     3  1855         6.00         7.10         2.40
# 3     2      1    1     4  1830         5.70         7.20         2.00
# 4     2      1    1     5  1844         7.40         8.30         4.20
#
#    Site-4 Temp  Site-5 Temp  ...  Site-2 GHI  Site-3 GHI  Site-4 GHI  \
# 0         7.10         5.90  ...           0           0           0
# 1         6.70         6.00  ...           0           0           0
# 2         7.20         6.30  ...           0           0           0
# 3         7.90         8.60  ...           0           0           0
# 4        11.40        12.40  ...           0           0           0
#
#    Site-5 GHI  Model NG  Model PK  Model BY  Model NU  Model SA  best_encoded
# 0           0  1,991.57  1,976.26  1,989.82  1,992.32  1,972.31             2
# 1           0  1,905.37  1,933.52  1,900.49  1,950.43  1,897.57             4
# 2           0  1,812.80  1,867.68  1,833.55  1,866.50  1,886.81             3
# 3           0  1,749.44  1,894.85  1,781.64  1,809.24  1,894.87             3
# 4           0  1,862.80  1,944.38  1,811.23  1,835.14  1,905.08             3
#
# [5 rows x 21 columns]

# %%
# Reverse mapping
inverse_mapping = {v: k for k, v in class_mapping.items()}

# Apply inverse mapping to predicted classes
test_data['best'] = test_data['best_encoded'].map(inverse_mapping)  # Assuming predictions are stored in 'best_encoded'
train_data['best_fcst'] = train_data['best_encoded_fcst'].map(inverse_mapping) 
test_data.head()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     2      1    1     1  2021         6.70         7.40         2.90
# 1     2      1    1     2  1923         6.20         7.10         2.50
# 2     2      1    1     3  1855         6.00         7.10         2.40
# 3     2      1    1     4  1830         5.70         7.20         2.00
# 4     2      1    1     5  1844         7.40         8.30         4.20
#
#    Site-4 Temp  Site-5 Temp  ...  Site-3 GHI  Site-4 GHI  Site-5 GHI  \
# 0         7.10         5.90  ...           0           0           0
# 1         6.70         6.00  ...           0           0           0
# 2         7.20         6.30  ...           0           0           0
# 3         7.90         8.60  ...           0           0           0
# 4        11.40        12.40  ...           0           0           0
#
#    Model NG  Model PK  Model BY  Model NU  Model SA  best_encoded      best
# 0  1,991.57  1,976.26  1,989.82  1,992.32  1,972.31             2  Model NU
# 1  1,905.37  1,933.52  1,900.49  1,950.43  1,897.57             4  Model NG
# 2  1,812.80  1,867.68  1,833.55  1,866.50  1,886.81             3  Model BY
# 3  1,749.44  1,894.85  1,781.64  1,809.24  1,894.87             3  Model BY
# 4  1,862.80  1,944.38  1,811.23  1,835.14  1,905.08             3  Model BY
#
# [5 rows x 22 columns]

# %%
# Populate 'best_pred' based on the chosen best method
test_data['best_pred'] = test_data.apply(lambda row: row[row['best']], axis=1)
train_data['best_pred_fcst'] = train_data.apply(lambda row: row[row['best_fcst']], axis=1)
test_data.head()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     2      1    1     1  2021         6.70         7.40         2.90
# 1     2      1    1     2  1923         6.20         7.10         2.50
# 2     2      1    1     3  1855         6.00         7.10         2.40
# 3     2      1    1     4  1830         5.70         7.20         2.00
# 4     2      1    1     5  1844         7.40         8.30         4.20
#
#    Site-4 Temp  Site-5 Temp  ...  Site-4 GHI  Site-5 GHI  Model NG  Model PK  \
# 0         7.10         5.90  ...           0           0  1,991.57  1,976.26
# 1         6.70         6.00  ...           0           0  1,905.37  1,933.52
# 2         7.20         6.30  ...           0           0  1,812.80  1,867.68
# 3         7.90         8.60  ...           0           0  1,749.44  1,894.85
# 4        11.40        12.40  ...           0           0  1,862.80  1,944.38
#
#    Model BY  Model NU  Model SA  best_encoded      best  best_pred
# 0  1,989.82  1,992.32  1,972.31             2  Model NU   1,992.32
# 1  1,900.49  1,950.43  1,897.57             4  Model NG   1,905.37
# 2  1,833.55  1,866.50  1,886.81             3  Model BY   1,833.55
# 3  1,781.64  1,809.24  1,894.87             3  Model BY   1,781.64
# 4  1,811.23  1,835.14  1,905.08             3  Model BY   1,811.23
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Regression to get weighted sum of 7 predictions

# %%
# Creating training data dropping columns not needed and also ground truth
X_train = train_data[methods] 
y_train = train_data['Load']
X_test = test_data[methods]
y_test = test_data['Load']

# %%
model = LinearRegression(fit_intercept = False)
model.fit(X_train, y_train) 

# The following gives the R-square score
model.score(X_train, y_train) 

# This is the coefficient Beta_1 to Beta_m
model.coef_
# Out:
# LinearRegression(fit_intercept=False)
# 0.8466731194497951
# array([0.06415487, 0.58101612, 0.09399755, 0.22459056, 0.02390409])

# %%
y_pred = model.predict(X_test)

# %%
train_data['weighted_pred'] = model.predict(X_train)
test_data['weighted_pred'] = model.predict(X_test)

# %%
train_data.head()
test_data.head()
# Out:
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     1      1    1     1  1997         8.00         8.20         5.30
# 1     1      1    1     2  1921         8.30         8.60         5.20
# 2     1      1    1     3  1861         8.10         8.80         5.10
# 3     1      1    1     4  1833         7.60         8.10         4.30
# 4     1      1    1     5  1847         7.30         7.50         4.00
#
#    Site-4 Temp  Site-5 Temp  ...  Model BY  Model NU  Model SA      best  \
# 0         9.40         8.10  ...  1,931.47  1,905.52  1,920.41  Model NG
# 1         8.60         7.10  ...  1,852.36  2,100.16  1,980.25  Model SA
# 2         8.70         6.20  ...  1,814.53  2,077.88  1,953.50  Model NG
# 3         8.50         6.00  ...  1,815.76  2,062.45  1,940.21  Model NG
# 4         8.60         6.90  ...  1,882.84  2,007.13  1,956.47  Model BY
#
#    best_pred  best_encoded  best_encoded_fcst  best_fcst  best_pred_fcst  \
# 0   1,935.31             4                  4   Model NG        1,935.31
# 1   1,980.25             1                  4   Model NG        1,860.35
# 2   1,829.12             4                  4   Model NG        1,829.12
# 3   1,817.96             4                  4   Model NG        1,817.96
# 4   1,882.84             3                  3   Model BY        1,882.84
#
#    weighted_pred
# 0       1,898.16
# 1       1,935.50
# 2       1,906.91
# 3       1,896.89
# 4       1,919.34
#
# [5 rows x 27 columns]
#    Year  Month  Day  Hour  Load  Site-1 Temp  Site-2 Temp  Site-3 Temp  \
# 0     2      1    1     1  2021         6.70         7.40         2.90
# 1     2      1    1     2  1923         6.20         7.10         2.50
# 2     2      1    1     3  1855         6.00         7.10         2.40
# 3     2      1    1     4  1830         5.70         7.20         2.00
# 4     2      1    1     5  1844         7.40         8.30         4.20
#
#    Site-4 Temp  Site-5 Temp  ...  Site-5 GHI  Model NG  Model PK  Model BY  \
# 0         7.10         5.90  ...           0  1,991.57  1,976.26  1,989.82
# 1         6.70         6.00  ...           0  1,905.37  1,933.52  1,900.49
# 2         7.20         6.30  ...           0  1,812.80  1,867.68  1,833.55
# 3         7.90         8.60  ...           0  1,749.44  1,894.85  1,781.64
# 4        11.40        12.40  ...           0  1,862.80  1,944.38  1,811.23
#
#    Model NU  Model SA  best_encoded      best  best_pred  weighted_pred
# 0  1,992.32  1,972.31             2  Model NU   1,992.32       1,954.51
# 1  1,950.43  1,897.57             4  Model NG   1,905.37       1,882.28
# 2  1,866.50  1,886.81             3  Model BY   1,833.55       1,846.66
# 3  1,809.24  1,894.87             3  Model BY   1,781.64       1,834.54
# 4  1,835.14  1,905.08             3  Model BY   1,811.23       1,855.44
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Residual based method using the best pred so far

# %%
# Creating Residual
train_data['Residuals'] = train_data['Load'] - train_data[pk] # old sa, by
# Creating training data dropping columns not needed and also ground truth
X_train = train_data[['Month', 'Hour', 'Site-1 Temp', 'Site-2 Temp',
       'Site-3 Temp', 'Site-4 Temp', 'Site-5 Temp', 'Site-1 GHI', 'Site-2 GHI',
       'Site-3 GHI', 'Site-4 GHI', 'Site-5 GHI']]
y_train = train_data['Residuals']
X_test = test_data[['Month', 'Hour', 'Site-1 Temp', 'Site-2 Temp',
       'Site-3 Temp', 'Site-4 Temp', 'Site-5 Temp', 'Site-1 GHI', 'Site-2 GHI',
       'Site-3 GHI', 'Site-4 GHI', 'Site-5 GHI']]

# Define the XGBoost regressor with specific hyperparameters
model = XGBRegressor(
        n_estimators=400,
        max_depth=5,
        learning_rate=0.05,
        subsample=1.0,
        colsample_bytree=0.6,
        objective='reg:squarederror',
        random_state=42
    )
# Train the model
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=400, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# test_data['Residuals'] = gb.predict(X_test)
test_data['Residuals'] = model.predict(X_test)
test_data['Res_pred'] = test_data['Residuals'] + test_data[pk] # old sa, by
train_data['Res_pred'] = model.predict(X_train) + train_data[pk]

# %% [markdown]
# ## ML-based corrections for best pred so far

# %%
# Creating training data dropping columns not needed and also ground truth
X_train = train_data[['Month', 'Hour', 'Site-1 Temp', 'Site-2 Temp',
       'Site-3 Temp', 'Site-4 Temp', 'Site-5 Temp', 'Site-1 GHI', 'Site-2 GHI',
       'Site-3 GHI', 'Site-4 GHI', 'Site-5 GHI', pk]] # old sa, by
y_train = train_data['Load']
X_test = test_data[['Month', 'Hour', 'Site-1 Temp', 'Site-2 Temp',
       'Site-3 Temp', 'Site-4 Temp', 'Site-5 Temp', 'Site-1 GHI', 'Site-2 GHI',
       'Site-3 GHI', 'Site-4 GHI', 'Site-5 GHI', pk]] # old sa, by

# Define the XGBoost regressor with specific hyperparameters
model = XGBRegressor(
        n_estimators=400,
        max_depth=5,
        learning_rate=0.05,
        subsample=1.0,
        colsample_bytree=0.6,
        objective='reg:squarederror',
        random_state=42
    )
# Train the model
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=400, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# test_data['Adj_pred'] = gb.predict(X_test)
test_data['Adj_pred'] = model.predict(X_test)
train_data['Adj_pred'] = model.predict(X_train)

# %% [markdown]
# ## Comparing Predictions

# %%
from sklearn.metrics import mean_absolute_error, median_absolute_error, r2_score, mean_squared_error

# List of prediction columns
prediction_columns = methods + ['best_pred', 'weighted_pred', 'Res_pred', 'Adj_pred']
train_pred_columns = methods + ['best_pred_fcst', 'weighted_pred', 'Res_pred', 'Adj_pred']

# Function to compute metrics
def compute_metrics(df, predictions, ground_truth):
    metrics = []
    for col in predictions:
        y_true = df[ground_truth]
        y_pred = df[col]
        mae = mean_absolute_error(y_true, y_pred)
        medae = median_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100  # Mean Absolute Percentage Error
        metrics.append([col, mae, medae, r2, rmse, mape])
    
    return pd.DataFrame(metrics, columns=['Prediction', 'MAE', 'MedAE', 'R-squared', 'RMSE', 'MAPE'])

# Compute and display metrics
train_metrics_df = compute_metrics(train_data, train_pred_columns, 'Load')
print(train_metrics_df)
test_metrics_df = compute_metrics(test_data, prediction_columns, 'Load')
# print(metrics_df)
# Out:
#        Prediction    MAE  MedAE  R-squared   RMSE  MAPE
# 0        Model PK 142.31 111.12       0.83 194.07  6.81
# 1        Model SA 145.02 114.64       0.83 191.10  7.06
# 2        Model NU 144.40 109.40       0.81 201.65  6.84
# 3        Model BY 141.95 107.99       0.81 201.48  6.68
# 4        Model NG 142.15 107.35       0.81 200.43  6.70
# 5  best_pred_fcst 104.91  75.28       0.89 151.33  5.04
# 6   weighted_pred 133.24 102.65       0.85 182.37  6.34
# 7        Res_pred  77.38  58.76       0.95 102.98  3.72
# 8        Adj_pred  73.62  55.66       0.96  98.63  3.54

# %%
train_metrics_df.head(12)
helper_methods.generate_results_latex(train_metrics_df)
# Out:
#        Prediction    MAE  MedAE  R-squared   RMSE  MAPE
# 0        Model PK 142.31 111.12       0.83 194.07  6.81
# 1        Model SA 145.02 114.64       0.83 191.10  7.06
# 2        Model NU 144.40 109.40       0.81 201.65  6.84
# 3        Model BY 141.95 107.99       0.81 201.48  6.68
# 4        Model NG 142.15 107.35       0.81 200.43  6.70
# 5  best_pred_fcst 104.91  75.28       0.89 151.33  5.04
# 6   weighted_pred 133.24 102.65       0.85 182.37  6.34
# 7        Res_pred  77.38  58.76       0.95 102.98  3.72
# 8        Adj_pred  73.62  55.66       0.96  98.63  3.54
# Model PK & 142.31 & 111.12 & 0.83 & 194.07 & 6.81 \\
# Model SA & 145.02 & 114.64 & 0.83 & 191.10 & 7.06 \\
# Model NU & 144.40 & 109.40 & 0.81 & 201.65 & 6.84 \\
# Model BY & 141.95 & 107.99 & 0.81 & 201.48 & 6.68 \\
# Model NG & 142.15 & 107.35 & 0.81 & 200.43 & 6.70 \\
# best_pred_fcst & 104.91 & 75.28 & 0.89 & 151.33 & 5.04 \\
# weighted_pred & 133.24 & 102.65 & 0.85 & 182.37 & 6.34 \\
# Res_pred & 77.38 & 58.76 & 0.95 & 102.98 & 3.72 \\
# Adj_pred & 73.62 & 55.66 & 0.96 & 98.63 & 3.54 \\

# %%
test_metrics_df.head(12)
helper_methods.generate_results_latex(test_metrics_df)
# Out:
#       Prediction    MAE  MedAE  R-squared   RMSE  MAPE
# 0       Model PK 126.57  98.44       0.83 167.47  6.03
# 1       Model SA 135.20 103.01       0.80 180.80  6.46
# 2       Model NU 134.65 104.88       0.81 178.54  6.46
# 3       Model BY 136.72 103.51       0.79 186.47  6.56
# 4       Model NG 133.53 102.87       0.80 179.89  6.41
# 5      best_pred 131.28 101.88       0.81 175.17  6.31
# 6  weighted_pred 136.74 110.04       0.81 179.10  6.47
# 7       Res_pred 177.35 154.13       0.69 225.15  8.55
# 8       Adj_pred 152.76 129.90       0.77 195.85  7.32
# Model PK & 126.57 & 98.44 & 0.83 & 167.47 & 6.03 \\
# Model SA & 135.20 & 103.01 & 0.80 & 180.80 & 6.46 \\
# Model NU & 134.65 & 104.88 & 0.81 & 178.54 & 6.46 \\
# Model BY & 136.72 & 103.51 & 0.79 & 186.47 & 6.56 \\
# Model NG & 133.53 & 102.87 & 0.80 & 179.89 & 6.41 \\
# best_pred & 131.28 & 101.88 & 0.81 & 175.17 & 6.31 \\
# weighted_pred & 136.74 & 110.04 & 0.81 & 179.10 & 6.47 \\
# Res_pred & 177.35 & 154.13 & 0.69 & 225.15 & 8.55 \\
# Adj_pred & 152.76 & 129.90 & 0.77 & 195.85 & 7.32 \\

# %%
methods # Used for best_pred and weighted_pred
# Out:
# ['Model PK', 'Model SA', 'Model NU', 'Model BY', 'Model NG']
